# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_men"

def calculate_bmis(directory):
    bmis = []
    genders = []
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                else:
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                print(f"Error processing file {filename}: {e}")
        else:
            print(f"Skipping non-image file {filename}")
    
    return bmis, genders

# Get BMIs and genders
bmis, genders = calculate_bmis(directory)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Define BMI categories (ranges)
    bmi_bins = [(0, 18.5), (18.5, 25), (25, 30), (30, 35), (35, 40), (40, float('inf'))]
    bmi_labels = ['Underweight', 'Normal', 'Overweight', 'Obese', 'Severely Obese', 'Morbidly Obese']

    # Group BMIs by gender and bin them
    bmi_by_gender = defaultdict(lambda: [0]*len(bmi_bins))
    overall_counts = [0]*len(bmi_bins)

    for bmi, gender in zip(bmis, genders):
        for i, (lower, upper) in enumerate(bmi_bins):
            if lower <= bmi < upper:  # BMI falls within the range
                bmi_by_gender[gender][i] += 1
                overall_counts[i] += 1
                break

    # Create the plot
    x = np.arange(len(bmi_labels))  # the label locations
    width = 0.25  # the width of the bars

    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Create bars for Male, Female, and Overall counts
    ax.bar(x - width, bmi_by_gender['M'], width, label='Male', color='blue')
    ax.bar(x, bmi_by_gender['F'], width, label='Female', color='red')
    ax.bar(x + width, overall_counts, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('BMI Categories')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender')
    ax.set_xticks(x)
    ax.set_xticklabels(bmi_labels)
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\all\crop_regroup\Fullkorean"

def calculate_bmis(directory):
    bmis = []
    genders = []
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                else:
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                print(f"Error processing file {filename}: {e}")
        else:
            print(f"Skipping non-image file {filename}")
    
    return bmis, genders

# Get BMIs and genders
bmis, genders = calculate_bmis(directory)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Define BMI categories (ranges)
    bmi_bins = [(0, 18.5), (18.5, 25), (25, 30), (30, 35), (35, 40), (40, float('inf'))]
    bmi_labels = ['Underweight', 'Normal', 'Overweight', 'Obese', 'Severely Obese', 'Morbidly Obese']

    # Group BMIs by gender and bin them
    bmi_by_gender = defaultdict(lambda: [0]*len(bmi_bins))
    overall_counts = [0]*len(bmi_bins)

    for bmi, gender in zip(bmis, genders):
        for i, (lower, upper) in enumerate(bmi_bins):
            if lower <= bmi < upper:  # BMI falls within the range
                bmi_by_gender[gender][i] += 1
                overall_counts[i] += 1
                break

    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')
    
    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")

    # Create the plot
    x = np.arange(len(bmi_labels))  # the label locations
    width = 0.25  # the width of the bars

    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Create bars for Male, Female, and Overall counts
    ax.bar(x - width, bmi_by_gender['M'], width, label='Male', color='blue')
    ax.bar(x, bmi_by_gender['F'], width, label='Female', color='red')
    ax.bar(x + width, overall_counts, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('BMI Categories')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender')
    ax.set_xticks(x)
    ax.set_xticklabels(bmi_labels)
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 1553
# Total females: 1198

# %%
import os

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\all\crop_regroup\Fullkorean"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To keep track of files that are skipped due to errors
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.lower().endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1].upper()  # 성별: M or F, convert to uppercase in case it's lowercase
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")
    
    return bmis, genders, skipped_files

# Get BMIs, genders, and skipped files
bmis, genders, skipped_files = calculate_bmis(directory)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')
    
    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {len(os.listdir(directory))}")
    
    # Print out the skipped files
    print(f"Skipped files ({len(skipped_files)}):")
    for skipped in skipped_files:
        print(f"- {skipped}")
# Out:
# Total males: 1553
# Total females: 1201
# Total images processed: 2754
# Total images: 2754
# Skipped files (0):

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\all\crop_regroup\Fullkorean"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")
    
    return bmis, genders, skipped_files

# Get BMIs, genders, and skipped files
bmis, genders, skipped_files = calculate_bmis(directory)

# Total number of files in the directory
total_files = len(os.listdir(directory))

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Define BMI categories (ranges)
    bmi_bins = [(0, 18.5), (18.5, 25), (25, 30), (30, 35), (35, 40), (40, float('inf'))]
    bmi_labels = ['Underweight', 'Normal', 'Overweight', 'Obese', 'Severely Obese', 'Morbidly Obese']

    # Group BMIs by gender and bin them
    bmi_by_gender = defaultdict(lambda: [0]*len(bmi_bins))
    overall_counts = [0]*len(bmi_bins)

    for bmi, gender in zip(bmis, genders):
        for i, (lower, upper) in enumerate(bmi_bins):
            if lower <= bmi < upper:  # BMI falls within the range
                bmi_by_gender[gender][i] += 1
                overall_counts[i] += 1
                break

    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")
    
    # Check for missing files
    missing_files = total_files - (male_count + female_count + len(skipped_files))
    print(f"Missing files (due to incorrect processing): {missing_files}")

    # Create the plot
    x = np.arange(len(bmi_labels))  # the label locations
    width = 0.25  # the width of the bars

    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Create bars for Male, Female, and Overall counts
    ax.bar(x - width, bmi_by_gender['M'], width, label='Male', color='blue')
    ax.bar(x, bmi_by_gender['F'], width, label='Female', color='red')
    ax.bar(x + width, overall_counts, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('BMI Categories')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender')
    ax.set_xticks(x)
    ax.set_xticklabels(bmi_labels)
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 1553
# Total females: 1198
# Total images processed: 2751
# Total images: 2754
# Skipped files (0):
# Missing files (due to incorrect processing): 3

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\all\crop_regroup\Fullkorean"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Define BMI categories (ranges)
    bmi_bins = [(0, 18.5), (18.5, 25), (25, 30), (30, 35), (35, 40), (40, float('inf'))]
    bmi_labels = ['Underweight', 'Normal', 'Overweight', 'Obese', 'Severely Obese', 'Morbidly Obese']

    # Group BMIs by gender and bin them
    bmi_by_gender = defaultdict(lambda: [0]*len(bmi_bins))
    overall_counts = [0]*len(bmi_bins)

    for bmi, gender in zip(bmis, genders):
        for i, (lower, upper) in enumerate(bmi_bins):
            if lower <= bmi < upper:  # BMI falls within the range
                bmi_by_gender[gender][i] += 1
                overall_counts[i] += 1
                break

    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Create the plot
    x = np.arange(len(bmi_labels))  # the label locations
    width = 0.25  # the width of the bars

    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Create bars for Male, Female, and Overall counts
    ax.bar(x - width, bmi_by_gender['M'], width, label='Male', color='blue')
    ax.bar(x, bmi_by_gender['F'], width, label='Female', color='red')
    ax.bar(x + width, overall_counts, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('BMI Categories')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender')
    ax.set_xticks(x)
    ax.set_xticklabels(bmi_labels)
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 1553
# Total females: 1198
# Total images processed: 2751
# Total images: 2754
# Skipped files (0):
# Missing files (due to incorrect processing): 0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_men"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Create the plot for BMI distribution between 0 and 80
    bins = np.arange(0, 81, 5)  # Creating bins from 0 to 80, in intervals of 5

    # Calculate male and female histograms separately
    male_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'M']
    female_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'F']

    # Width for side-by-side bars
    width = 2.0  # Width of the bars

    # Calculate histogram counts for males and females
    male_hist, _ = np.histogram(male_bmis, bins=bins)
    female_hist, _ = np.histogram(female_bmis, bins=bins)

    # X locations for the bars (centered for each bin)
    bin_centers = bins[:-1] + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male and Female
    ax.bar(bin_centers - width / 2, male_hist, width, label='Male', color='blue')
    ax.bar(bin_centers + width / 2, female_hist, width, label='Female', color='red')

    # Add labels and title
    ax.set_xlabel('BMI')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender (BMI 0 - 80)')
    ax.set_xticks(np.arange(0, 81, 5))  # Setting x-ticks at every 5 BMI points
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 9900
# Total females: 0
# Total images processed: 9900
# Total images: 9900
# Skipped files (0):
# Missing files (due to incorrect processing): 0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_men"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Separate BMI data by gender
    male_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'M']
    female_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'F']

    # Calculate BMI ranges for males and females
    if male_bmis:
        male_min_bmi = min(male_bmis)
        male_max_bmi = max(male_bmis)
        print(f"Male BMI Range: {male_min_bmi:.2f} - {male_max_bmi:.2f}")
    else:
        print("No male BMI data available.")

    if female_bmis:
        female_min_bmi = min(female_bmis)
        female_max_bmi = max(female_bmis)
        print(f"Female BMI Range: {female_min_bmi:.2f} - {female_max_bmi:.2f}")
    else:
        print("No female BMI data available.")

    # Create the plot for BMI distribution between 0 and 80
    bins = np.arange(0, 81, 5)  # Creating bins from 0 to 80, in intervals of 5

    # Width for side-by-side bars
    width = 2.0  # Width of the bars

    # Calculate histogram counts for males and females
    male_hist, _ = np.histogram(male_bmis, bins=bins)
    female_hist, _ = np.histogram(female_bmis, bins=bins)

    # X locations for the bars (centered for each bin)
    bin_centers = bins[:-1] + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male and Female
    ax.bar(bin_centers - width / 2, male_hist, width, label='Male', color='blue')
    ax.bar(bin_centers + width / 2, female_hist, width, label='Female', color='red')

    # Add labels and title
    ax.set_xlabel('BMI')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender (BMI 0 - 80)')
    ax.set_xticks(np.arange(0, 81, 5))  # Setting x-ticks at every 5 BMI points
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 9900
# Total females: 0
# Total images processed: 9900
# Total images: 9900
# Skipped files (0):
# Missing files (due to incorrect processing): 0
# Male BMI Range: 16.91 - 35.37
# No female BMI data available.

# %%
import os
import shutil
import random

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_all"
destination_directory = r"C:\Users\USER\Desktop\korean\reselect"  # Directory to copy selected files

def calculate_bmis_and_copy(directory, destination_directory, max_files_per_range=300):
    bmis = []
    genders = []
    processed_files = []  # To track successfully processed files
    file_mapping = {}  # To store BMI along with filename

    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return

    # Create destination directory if it does not exist
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:
                    gender = parts[1]  # 성별: M or F
                    if gender != 'M':  # 남성만 처리
                        continue  # 성별이 남성이 아닌 파일은 무시

                    height_m = int(parts[3]) / 100000  # cm to meter
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg conversion
                    bmi = weight_kg / (height_m ** 2)  # BMI calculation
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                    file_mapping[filename] = bmi  # Map the file to its BMI
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    if not bmis:
        print("No valid BMI data found.")
        return

    # Separate BMI data into more granular ranges
    very_low_bmi_files = [filename for filename, bmi in file_mapping.items() if bmi < 16]
    low_bmi_files = [filename for filename, bmi in file_mapping.items() if 16 <= bmi < 18.5]
    normal_bmi_files = [filename for filename, bmi in file_mapping.items() if 18.5 <= bmi < 23]
    slightly_overweight_bmi_files = [filename for filename, bmi in file_mapping.items() if 23 <= bmi < 25]
    overweight_bmi_files = [filename for filename, bmi in file_mapping.items() if 25 <= bmi < 30]
    obese_bmi_files = [filename for filename, bmi in file_mapping.items() if bmi >= 30]

    # Limit the number of files to copy per BMI range (300 max)
    selected_very_low_bmi_files = random.sample(very_low_bmi_files, min(len(very_low_bmi_files), max_files_per_range))
    selected_low_bmi_files = random.sample(low_bmi_files, min(len(low_bmi_files), max_files_per_range))
    selected_normal_bmi_files = random.sample(normal_bmi_files, min(len(normal_bmi_files), max_files_per_range))
    selected_slightly_overweight_bmi_files = random.sample(slightly_overweight_bmi_files, min(len(slightly_overweight_bmi_files), max_files_per_range))
    selected_overweight_bmi_files = random.sample(overweight_bmi_files, min(len(overweight_bmi_files), max_files_per_range))
    selected_obese_bmi_files = random.sample(obese_bmi_files, min(len(obese_bmi_files), max_files_per_range))

    # Copy the selected files to the destination directory
    copied_files = []
    for file_list in [
        selected_very_low_bmi_files, selected_low_bmi_files, selected_normal_bmi_files, 
        selected_slightly_overweight_bmi_files, selected_overweight_bmi_files, selected_obese_bmi_files]:
        for file in file_list:
            source_path = os.path.join(directory, file)
            dest_path = os.path.join(destination_directory, file)
            shutil.copy2(source_path, dest_path)  # Use copy2 to retain metadata
            copied_files.append(file)

    # Print the result
    print(f"Total files copied: {len(copied_files)}")
    print(f"Files copied for very low BMI range (<16): {len(selected_very_low_bmi_files)}")
    print(f"Files copied for low BMI range (16 <= BMI < 18.5): {len(selected_low_bmi_files)}")
    print(f"Files copied for normal BMI range (18.5 <= BMI < 23): {len(selected_normal_bmi_files)}")
    print(f"Files copied for slightly overweight BMI range (23 <= BMI < 25): {len(selected_slightly_overweight_bmi_files)}")
    print(f"Files copied for overweight BMI range (25 <= BMI < 30): {len(selected_overweight_bmi_files)}")
    print(f"Files copied for obese BMI range (>=30): {len(selected_obese_bmi_files)}")

    return copied_files

# Call the function to calculate BMIs and copy files with 300 files per range
copied_files = calculate_bmis_and_copy(directory, destination_directory, max_files_per_range=300)

# Print copied files summary
if copied_files:
    print("List of copied files:")
    for copied_file in copied_files:
        print(f"- {copied_file}")
# Out:
# Total files copied: 1340
# Files copied for very low BMI range (<16): 0
# Files copied for low BMI range (16 <= BMI < 18.5): 140
# Files copied for normal BMI range (18.5 <= BMI < 23): 300
# Files copied for slightly overweight BMI range (23 <= BMI < 25): 300
# Files copied for overweight BMI range (25 <= BMI < 30): 300
# Files copied for obese BMI range (>=30): 300
# List of copied files:
# - 9046_M_77_162100_4690000.png
# - 9040_M_77_162100_4690000.png
# - 1783_M_20_175600_5340000.png
# - 9041_M_77_162100_4690000.png
# - 1788_M_20_175600_5340000.png
# - 9049_M_77_162100_4690000.png
# - 1534_M_27_176700_5580000.png
# - 1535_M_27_176700_5580000.png
# - 1793_M_20_175600_5340000.png
# - 2615_M_25_179300_5940000.png
# - 0670_M_27_180900_5730000.png
# - 0535_M_78_166000_4660000.png
# - 5104_M_29_181400_5890000.png
# - 1780_M_20_175600_5340000.png
# - 9045_M_77_162100_4690000.png
# - 2606_M_25_179300_5940000.png
# - 9055_M_77_162100_4690000.png
# - 2607_M_25_179300_5940000.png
# ...

# %%
import os
import shutil
import random

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_all"
destination_directory = r"C:\Users\USER\Desktop\korean\reselect"  # Directory to copy selected files

def calculate_bmis_and_copy(directory, destination_directory, max_files_per_range=300):
    bmis = []
    genders = []
    processed_files = []  # To track successfully processed files
    file_mapping = {}  # To store BMI along with filename

    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return

    # Create destination directory if it does not exist
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:
                    gender = parts[1]  # 성별: M or F
                    if gender != 'F':  # 남성만 처리
                        continue  # 성별이 남성이 아닌 파일은 무시

                    height_m = int(parts[3]) / 100000  # cm to meter
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg conversion
                    bmi = weight_kg / (height_m ** 2)  # BMI calculation
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                    file_mapping[filename] = bmi  # Map the file to its BMI
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    if not bmis:
        print("No valid BMI data found.")
        return

    # Separate BMI data into more granular ranges
    very_low_bmi_files = [filename for filename, bmi in file_mapping.items() if bmi < 16]
    low_bmi_files = [filename for filename, bmi in file_mapping.items() if 16 <= bmi < 18.5]
    normal_bmi_files = [filename for filename, bmi in file_mapping.items() if 18.5 <= bmi < 23]
    slightly_overweight_bmi_files = [filename for filename, bmi in file_mapping.items() if 23 <= bmi < 25]
    overweight_bmi_files = [filename for filename, bmi in file_mapping.items() if 25 <= bmi < 30]
    obese_bmi_files = [filename for filename, bmi in file_mapping.items() if bmi >= 30]

    # Limit the number of files to copy per BMI range (300 max)
    selected_very_low_bmi_files = random.sample(very_low_bmi_files, min(len(very_low_bmi_files), max_files_per_range))
    selected_low_bmi_files = random.sample(low_bmi_files, min(len(low_bmi_files), max_files_per_range))
    selected_normal_bmi_files = random.sample(normal_bmi_files, min(len(normal_bmi_files), max_files_per_range))
    selected_slightly_overweight_bmi_files = random.sample(slightly_overweight_bmi_files, min(len(slightly_overweight_bmi_files), max_files_per_range))
    selected_overweight_bmi_files = random.sample(overweight_bmi_files, min(len(overweight_bmi_files), max_files_per_range))
    selected_obese_bmi_files = random.sample(obese_bmi_files, min(len(obese_bmi_files), max_files_per_range))

    # Copy the selected files to the destination directory
    copied_files = []
    for file_list in [
        selected_very_low_bmi_files, selected_low_bmi_files, selected_normal_bmi_files, 
        selected_slightly_overweight_bmi_files, selected_overweight_bmi_files, selected_obese_bmi_files]:
        for file in file_list:
            source_path = os.path.join(directory, file)
            dest_path = os.path.join(destination_directory, file)
            shutil.copy2(source_path, dest_path)  # Use copy2 to retain metadata
            copied_files.append(file)

    # Print the result
    print(f"Total files copied: {len(copied_files)}")
    print(f"Files copied for very low BMI range (<16): {len(selected_very_low_bmi_files)}")
    print(f"Files copied for low BMI range (16 <= BMI < 18.5): {len(selected_low_bmi_files)}")
    print(f"Files copied for normal BMI range (18.5 <= BMI < 23): {len(selected_normal_bmi_files)}")
    print(f"Files copied for slightly overweight BMI range (23 <= BMI < 25): {len(selected_slightly_overweight_bmi_files)}")
    print(f"Files copied for overweight BMI range (25 <= BMI < 30): {len(selected_overweight_bmi_files)}")
    print(f"Files copied for obese BMI range (>=30): {len(selected_obese_bmi_files)}")

    return copied_files

# Call the function to calculate BMIs and copy files with 300 files per range
copied_files = calculate_bmis_and_copy(directory, destination_directory, max_files_per_range=300)

# Print copied files summary
if copied_files:
    print("List of copied files:")
    for copied_file in copied_files:
        print(f"- {copied_file}")
# Out:
# Total files copied: 1440
# Files copied for very low BMI range (<16): 80
# Files copied for low BMI range (16 <= BMI < 18.5): 300
# Files copied for normal BMI range (18.5 <= BMI < 23): 300
# Files copied for slightly overweight BMI range (23 <= BMI < 25): 300
# Files copied for overweight BMI range (25 <= BMI < 30): 300
# Files copied for obese BMI range (>=30): 160
# List of copied files:
# - 9424_F_74_153200_3350000.png
# - 9177_F_73_149500_600000.png
# - 9439_F_74_153200_3350000.png
# - 0555_F_26_161100_3970000.png
# - 0559_F_26_161100_3970000.png
# - 0554_F_26_161100_3970000.png
# - 0548_F_26_161100_3970000.png
# - 1109_F_41_160900_4010000.png
# - 9435_F_74_153200_3350000.png
# - 9171_F_73_149500_600000.png
# - 9168_F_73_149500_600000.png
# - 9421_F_74_153200_3350000.png
# - 9164_F_73_149500_600000.png
# - 9434_F_74_153200_3350000.png
# - 9170_F_73_149500_600000.png
# - 1119_F_41_160900_4010000.png
# - 0542_F_26_161100_3970000.png
# - 1100_F_41_160900_4010000.png
# ...

# %%
import os
import shutil

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_men"
destination_directory = r"C:\Users\USER\Desktop\korean\reselect"  # Directory to move selected files

def calculate_bmis_and_move(directory, destination_directory, min_bmi=16.91, max_bmi=35.37):
    bmis = []
    genders = []
    processed_files = []  # To track successfully processed files
    file_mapping = {}  # To store BMI along with filename

    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return

    # Create destination directory if it does not exist
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm to meter
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg conversion
                    bmi = weight_kg / (height_m ** 2)  # BMI calculation
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                    file_mapping[filename] = bmi  # Map the file to its BMI
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

    if not bmis:
        print("No valid BMI data found.")
        return

    # Filter files within the specific BMI range
    files_to_move = [filename for filename, bmi in file_mapping.items() if min_bmi <= bmi <= max_bmi]

    # Move the selected files to the destination directory
    moved_files = []
    for file in files_to_move:
        source_path = os.path.join(directory, file)
        dest_path = os.path.join(destination_directory, file)
        shutil.move(source_path, dest_path)
        moved_files.append(file)

    # Print the result
    print(f"Total files moved: {len(moved_files)}")
    if moved_files:
        print("Files moved based on BMI range:")
        for moved_file in moved_files:
            print(f"- {moved_file}")

    return moved_files

# Call the function to calculate BMIs and move files within the specific BMI range
moved_files = calculate_bmis_and_move(directory, destination_directory)

# Print moved files summary
if moved_files:
    print("List of moved files:")
    for moved_file in moved_files:
        print(f"- {moved_file}")
# Out:
# Total files moved: 9900
# Files moved based on BMI range:
# - 0000_M_22_174400_8150000.png
# - 0001_M_22_174400_8150000.png
# - 0002_M_22_174400_8150000.png
# - 0003_M_22_174400_8150000.png
# - 0004_M_22_174400_8150000.png
# - 0005_M_22_174400_8150000.png
# - 0006_M_22_174400_8150000.png
# - 0007_M_22_174400_8150000.png
# - 0008_M_22_174400_8150000.png
# - 0009_M_22_174400_8150000.png
# - 0010_M_22_174400_8150000.png
# - 0011_M_22_174400_8150000.png
# - 0012_M_22_174400_8150000.png
# - 0013_M_22_174400_8150000.png
# - 0014_M_22_174400_8150000.png
# - 0015_M_22_174400_8150000.png
# - 0016_M_22_174400_8150000.png
# - 0017_M_22_174400_8150000.png
# - 0018_M_22_174400_8150000.png
# - 0019_M_22_174400_8150000.png
# - 0020_M_39_170200_8690000.png
# - 0021_M_39_170200_8690000.png
# - 0022_M_39_170200_8690000.png
# - 0023_M_39_170200_8690000.png
# - 0024_M_39_170200_8690000.png
# - 0025_M_39_170200_8690000.png
# - 0026_M_39_170200_8690000.png
# - 0027_M_39_170200_8690000.png
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_women"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Create the plot for BMI distribution between 0 and 80
    bins = np.arange(0, 81, 5)  # Creating bins from 0 to 80, in intervals of 5

    # Calculate male and female histograms separately
    male_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'M']
    female_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'F']

    # Width for side-by-side bars
    width = 2.0  # Width of the bars

    # Calculate histogram counts for males and females
    male_hist, _ = np.histogram(male_bmis, bins=bins)
    female_hist, _ = np.histogram(female_bmis, bins=bins)

    # X locations for the bars (centered for each bin)
    bin_centers = bins[:-1] + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male and Female
    ax.bar(bin_centers - width / 2, male_hist, width, label='Male', color='blue')
    ax.bar(bin_centers + width / 2, female_hist, width, label='Female', color='red')

    # Add labels and title
    ax.set_xlabel('BMI')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender (BMI 0 - 80)')
    ax.set_xticks(np.arange(0, 81, 5))  # Setting x-ticks at every 5 BMI points
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 0
# Total females: 9840
# Total images processed: 9840
# Total images: 9840
# Skipped files (0):
# Missing files (due to incorrect processing): 0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_all"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Create the plot for BMI distribution between 0 and 80
    bins = np.arange(0, 81, 5)  # Creating bins from 0 to 80, in intervals of 5

    # Calculate male and female histograms separately
    male_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'M']
    female_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'F']

    # Width for side-by-side bars
    width = 2.0  # Width of the bars

    # Calculate histogram counts for males and females
    male_hist, _ = np.histogram(male_bmis, bins=bins)
    female_hist, _ = np.histogram(female_bmis, bins=bins)

    # X locations for the bars (centered for each bin)
    bin_centers = bins[:-1] + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male and Female
    ax.bar(bin_centers - width / 2, male_hist, width, label='Male', color='blue')
    ax.bar(bin_centers + width / 2, female_hist, width, label='Female', color='red')

    # Add labels and title
    ax.set_xlabel('BMI')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender (BMI 0 - 80)')
    ax.set_xticks(np.arange(0, 81, 5))  # Setting x-ticks at every 5 BMI points
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 9900
# Total females: 9840
# Total images processed: 19740
# Total images: 19740
# Skipped files (0):
# Missing files (due to incorrect processing): 0

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# 파일이 있는 디렉토리 경로 설정
directory = r'C:\Users\USER\Desktop\korean\allmen'

# BMI 계산 함수
def calculate_bmi(height, weight):
    return weight / (height / 100) ** 2

# 빈 리스트 생성
heights = []
weights = []
bmis = []

# 파일 목록 읽기
for filename in os.listdir(directory):
    if filename.endswith(".jpg"):
        # 파일명에서 키와 몸무게 추출
        match = re.search(r'_(\d{4})_(\d{3})\.jpg$', filename)
        if match:
            height = int(match.group(1)) / 10  # 소수점을 고려하여 cm 단위로 변환
            weight = int(match.group(2)) / 10  # 소수점을 고려하여 kg 단위로 변환
            bmi = calculate_bmi(height, weight)
            
            heights.append(height)
            weights.append(weight)
            bmis.append(bmi)

# 데이터프레임으로 변환
df = pd.DataFrame({
    'Height (cm)': heights,
    'Weight (kg)': weights,
    'BMI': bmis
})

# BMI 결과 출력
print(df)

# BMI 분포 시각화
plt.hist(bmis, bins=10, edgecolor='black')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()
# Out:
#        Height (cm)  Weight (kg)        BMI
# 0            174.4         81.5  26.795672
# 1            174.4         81.5  26.795672
# 2            174.4         81.5  26.795672
# 3            174.4         81.5  26.795672
# 4            174.4         81.5  26.795672
# ...            ...          ...        ...
# 17671        171.2         65.6  22.381867
# 17672        171.2         65.6  22.381867
# 17673        171.2         65.6  22.381867
# 17674        171.2         65.6  22.381867
# 17675        171.2         65.6  22.381867
#
# [17676 rows x 3 columns]

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# 파일이 있는 디렉토리 경로 설정
directory = r'C:\Users\USER\Desktop\korean\allmen'

# BMI 계산 함수
def calculate_bmi(height, weight):
    return weight / (height / 100) ** 2

# 빈 리스트 생성
heights = []
weights = []
bmis = []

# 파일 목록 읽기
for filename in os.listdir(directory):
    if filename.endswith(".jpg"):
        # 파일명에서 키와 몸무게 추출
        match = re.search(r'_(\d{4})_(\d{3})\.jpg$', filename)
        if match:
            height = int(match.group(1)) / 10  # 소수점을 고려하여 cm 단위로 변환
            weight = int(match.group(2)) / 10  # 소수점을 고려하여 kg 단위로 변환
            bmi = calculate_bmi(height, weight)
            
            heights.append(height)
            weights.append(weight)
            bmis.append(bmi)

# 데이터프레임으로 변환
df = pd.DataFrame({
    'Height (cm)': heights,
    'Weight (kg)': weights,
    'BMI': bmis
})

# BMI 결과 출력
print(df)

# BMI 범위 설정 (BMI ranges for underweight, normal, overweight, etc.)
bmi_bins = [0, 18.5, 24.9, 29.9, 34.9, 39.9, 50]  # BMI 구간 정의
bmi_labels = ['Underweight (<18.5)', 'Normal (18.5-24.9)', 'Overweight (25-29.9)', 
              'Obese Class I (30-34.9)', 'Obese Class II (35-39.9)', 'Obese Class III (≥40)']

# 데이터프레임에 BMI 범주 추가
df['BMI Category'] = pd.cut(df['BMI'], bins=bmi_bins, labels=bmi_labels, right=False)

# BMI 분포 출력
print(df['BMI Category'].value_counts())

# BMI 범위 분포 시각화
plt.hist(df['BMI'], bins=bmi_bins, edgecolor='black')
plt.xticks(bmi_bins)
plt.title('BMI Distribution by Range')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Empty DataFrame
# Columns: [Height (cm), Weight (kg), BMI]
# Index: []
# Underweight (<18.5)         0
# Normal (18.5-24.9)          0
# Overweight (25-29.9)        0
# Obese Class I (30-34.9)     0
# Obese Class II (35-39.9)    0
# Obese Class III (≥40)       0
# Name: BMI Category, dtype: int64

# %%
# BMI 리스트에서 최소값과 최대값 확인
min_bmi = min(bmis)
max_bmi = max(bmis)

print(f"최소 BMI: {min_bmi}")
print(f"최대 BMI: {max_bmi}")
# Out:
# 최소 BMI: 16.911017564232836
# 최대 BMI: 34.40807514754437

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# 파일이 있는 디렉토리 경로 설정
directory = r'C:\Users\USER\Desktop\korean\allwomen'

# BMI 계산 함수
def calculate_bmi(height, weight):
    return weight / (height / 100) ** 2

# 빈 리스트 생성
heights = []
weights = []
bmis = []

# 파일 목록 읽기
for filename in os.listdir(directory):
    if filename.endswith(".jpg"):
        # 파일명에서 키와 몸무게 추출
        match = re.search(r'_(\d{4})_(\d{3})\.jpg$', filename)
        if match:
            height = int(match.group(1)) / 10  # 소수점을 고려하여 cm 단위로 변환
            weight = int(match.group(2)) / 10  # 소수점을 고려하여 kg 단위로 변환
            bmi = calculate_bmi(height, weight)
            
            heights.append(height)
            weights.append(weight)
            bmis.append(bmi)

# 데이터프레임으로 변환
df = pd.DataFrame({
    'Height (cm)': heights,
    'Weight (kg)': weights,
    'BMI': bmis
})

# BMI 결과 출력
print(df)

# BMI 분포 시각화
plt.hist(bmis, bins=10, edgecolor='black')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()
# Out:
#        Height (cm)  Weight (kg)        BMI
# 0            161.1         59.2  22.810281
# 1            161.1         59.2  22.810281
# 2            161.1         59.2  22.810281
# 3            161.1         59.2  22.810281
# 4            161.1         59.2  22.810281
# ...            ...          ...        ...
# 17671        155.7         63.3  26.111179
# 17672        155.7         63.3  26.111179
# 17673        155.7         63.3  26.111179
# 17674        155.7         63.3  26.111179
# 17675        155.7         63.3  26.111179
#
# [17676 rows x 3 columns]

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_all"

def calculate_bmis(directory):
    bmis = []
    genders = []
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    
    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, skipped_files, processed_files

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    processed_files.append(filename)  # Log successful processing
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, skipped_files, processed_files

# Get BMIs, genders, skipped files, and processed files
bmis, genders, skipped_files, processed_files = calculate_bmis(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Create the plot for BMI distribution between 0 and 80
    bins = np.arange(0, 81, 5)  # Creating bins from 0 to 80, in intervals of 5

    # Calculate male, female, and overall histograms
    male_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'M']
    female_bmis = [bmi for bmi, gender in zip(bmis, genders) if gender == 'F']
    overall_bmis = bmis  # Overall includes both males and females

    # Width for side-by-side bars
    width = 1.5  # Width of the bars

    # Calculate histogram counts for males, females, and overall
    male_hist, _ = np.histogram(male_bmis, bins=bins)
    female_hist, _ = np.histogram(female_bmis, bins=bins)
    overall_hist, _ = np.histogram(overall_bmis, bins=bins)

    # X locations for the bars (centered for each bin)
    bin_centers = bins[:-1] + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male, Female, and Overall
    ax.bar(bin_centers - width, male_hist, width, label='Male', color='blue')
    ax.bar(bin_centers, female_hist, width, label='Female', color='red')
    ax.bar(bin_centers + width, overall_hist, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('BMI')
    ax.set_ylabel('Count')
    ax.set_title('BMI Distribution by Gender and Overall (BMI 0 - 80)')
    ax.set_xticks(np.arange(0, 81, 5))  # Setting x-ticks at every 5 BMI points
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 9900
# Total females: 9840
# Total images processed: 19740
# Total images: 19740
# Skipped files (0):
# Missing files (due to incorrect processing): 0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Directory where your image files are stored
directory = r"C:\Users\USER\Desktop\korean\rename_men"

def calculate_bmis_and_age_distribution(directory):
    bmis = []
    genders = []
    ages = []  # List to store ages
    skipped_files = []  # To track skipped files
    processed_files = []  # To track successfully processed files
    age_distribution = defaultdict(lambda: {'M': 0, 'F': 0, 'Overall': 0})  # Track age distribution for male, female, and overall

    # Check if the directory exists
    if not os.path.exists(directory):
        print(f"Directory {directory} does not exist.")
        return bmis, genders, ages, skipped_files, processed_files, age_distribution

    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Ensure the file follows the expected pattern and ends with .png
        if filename.endswith(".png"):
            try:
                # Split filename based on underscores
                parts = filename.split('_')
                if len(parts) >= 5:  # Expecting at least 5 parts in the name
                    gender = parts[1]  # 성별: M or F
                    age = int(parts[2])  # Age of the person
                    height_m = int(parts[3]) / 100000  # cm 단위로 되어있는 것을 meter로 변환
                    weight_kg = int(parts[4].split('.')[0]) / 100000  # kg 단위로 변환
                    bmi = weight_kg / (height_m ** 2)  # BMI 계산
                    bmis.append(bmi)
                    genders.append(gender)
                    ages.append(age)
                    processed_files.append(filename)  # Log successful processing
                    
                    # Update age distribution
                    age_distribution[age][gender] += 1
                    age_distribution[age]['Overall'] += 1
                else:
                    skipped_files.append(filename)
                    print(f"Filename {filename} does not match the expected pattern.")
            except Exception as e:
                skipped_files.append(filename)
                print(f"Error processing file {filename}: {e}")
        else:
            skipped_files.append(filename)
            print(f"Skipping non-image file {filename}")

    return bmis, genders, ages, skipped_files, processed_files, age_distribution

# Get BMIs, genders, skipped files, processed files, and age distribution
bmis, genders, ages, skipped_files, processed_files, age_distribution = calculate_bmis_and_age_distribution(directory)

# Total number of files in the directory
all_files = set(os.listdir(directory))
total_files = len(all_files)

# If no valid data was found, alert the user
if not bmis or not genders:
    print("No valid BMI data could be calculated.")
else:
    # Count total number of males and females
    male_count = genders.count('M')
    female_count = genders.count('F')

    # Print the results
    print(f"Total males: {male_count}")
    print(f"Total females: {female_count}")
    print(f"Total images processed: {male_count + female_count}")
    print(f"Total images: {total_files}")
    print(f"Skipped files ({len(skipped_files)}):")
    
    if skipped_files:
        for skipped in skipped_files:
            print(f"- {skipped}")

    # Check for missing files (files that were not processed)
    missing_files = all_files - set(processed_files + skipped_files)
    print(f"Missing files (due to incorrect processing): {len(missing_files)}")

    if missing_files:
        print("List of missing files:")
        for missing in missing_files:
            print(f"- {missing}")

    # Print age distribution
    print("\nAge Distribution:")
    for age in sorted(age_distribution.keys()):
        print(f"Age {age}: Male - {age_distribution[age]['M']}, Female - {age_distribution[age]['F']}, Overall - {age_distribution[age]['Overall']}")

    # Plot age distribution
    age_bins = np.arange(min(ages), max(ages) + 1, 5)  # Create age bins with a step of 5

    # Create separate lists for male, female, and overall counts based on the age bins
    male_age_counts = [sum(age_distribution[age]['M'] for age in range(age_bin, age_bin + 5)) for age_bin in age_bins]
    female_age_counts = [sum(age_distribution[age]['F'] for age in range(age_bin, age_bin + 5)) for age_bin in age_bins]
    overall_age_counts = [sum(age_distribution[age]['Overall'] for age in range(age_bin, age_bin + 5)) for age_bin in age_bins]

    width = 1.5  # Width of the bars

    # X locations for the bars (centered for each bin)
    bin_centers = age_bins + width / 2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create side-by-side bars for Male, Female, and Overall age distributions
    ax.bar(bin_centers - width, male_age_counts, width, label='Male', color='blue')
    ax.bar(bin_centers, female_age_counts, width, label='Female', color='red')
    ax.bar(bin_centers + width, overall_age_counts, width, label='Overall', color='green')

    # Add labels and title
    ax.set_xlabel('Age')
    ax.set_ylabel('Count')
    ax.set_title('Age Distribution by Gender and Overall')
    ax.set_xticks(age_bins + width / 2)
    ax.set_xticklabels([f"{int(age_bin)}-{int(age_bin+4)}" for age_bin in age_bins])  # Label age ranges (e.g., 20-24)
    ax.legend()

    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Total males: 9900
# Total females: 0
# Total images processed: 9900
# Total images: 9900
# Skipped files (0):
# Missing files (due to incorrect processing): 0
#
# Age Distribution:
# Age 20: Male - 20, Female - 0, Overall - 20
# Age 21: Male - 20, Female - 0, Overall - 20
# Age 22: Male - 200, Female - 0, Overall - 200
# Age 23: Male - 160, Female - 0, Overall - 160
# Age 24: Male - 280, Female - 0, Overall - 280
# Age 25: Male - 140, Female - 0, Overall - 140
# Age 26: Male - 180, Female - 0, Overall - 180
# Age 27: Male - 300, Female - 0, Overall - 300
# Age 28: Male - 120, Female - 0, Overall - 120
# Age 29: Male - 100, Female - 0, Overall - 100
# Age 30: Male - 320, Female - 0, Overall - 320
# Age 31: Male - 160, Female - 0, Overall - 160
# Age 32: Male - 260, Female - 0, Overall - 260
# Age 33: Male - 120, Female - 0, Overall - 120
# Age 34: Male - 240, Female - 0, Overall - 240
# Age 35: Male - 140, Female - 0, Overall - 140
# Age 36: Male - 200, Female - 0, Overall - 200
# ...

# %% [markdown]
# # 남성만 비교했을 경우  - 연령대는 그래도 다양함
# # 학습할때 뽑아서 사용하는게 좋을듯

# %%
import os
import numpy as np
from collections import defaultdict

def check_bmi_distribution(bmis, genders, processed_files, bins=np.arange(0, 81, 5)):
    # Create a dictionary to hold files by BMI bin
    binned_files = defaultdict(list)
    
    # Bin the files by BMI ranges
    for bmi, gender, filename in zip(bmis, genders, processed_files):
        for i in range(len(bins) - 1):
            if bins[i] <= bmi < bins[i + 1]:
                binned_files[i].append(filename)
                break
    
    # Print out how many files exist in each BMI bin
    print("BMI Range Distribution:")
    for i in range(len(bins) - 1):
        print(f"{bins[i]} - {bins[i + 1]}: {len(binned_files[i])} files")
    
    return binned_files

# BMI 구간별로 파일 수를 확인
binned_files = check_bmi_distribution(bmis, genders, processed_files)
# Out:
# BMI Range Distribution:
# 0 - 5: 20 files
# 5 - 10: 0 files
# 10 - 15: 20 files
# 15 - 20: 2260 files
# 20 - 25: 11360 files
# 25 - 30: 5500 files
# 30 - 35: 560 files
# 35 - 40: 20 files
# 40 - 45: 0 files
# 45 - 50: 0 files
# 50 - 55: 0 files
# 55 - 60: 0 files
# 60 - 65: 0 files
# 65 - 70: 0 files
# 70 - 75: 0 files
# 75 - 80: 0 files

# %%
import os
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

def load_files_from_directory(directory):
    """Load files from the specified directory and extract Gender, Height (in mm), and Weight (in grams) from filenames."""
    bmis = []
    genders = []
    processed_files = []

    for filename in os.listdir(directory):
        if filename.endswith(".png"):  # Now we're checking for PNG files
            # Assuming filename format: "{ID}_{Gender}_{Age}_{Height in mm}_{Weight in grams}.png"
            parts = filename.replace(".png", "").split("_")
            if len(parts) == 5:
                gender = parts[1]
                height_mm = float(parts[3])  # Height in millimeters
                weight_g = float(parts[4])   # Weight in grams
                
                # Convert height to meters and weight to kilograms
                height_m = height_mm / 1000
                weight_kg = weight_g / 1000
                
                # Calculate BMI
                bmi = weight_kg / (height_m ** 2)
                
                genders.append(gender)
                bmis.append(bmi)
                processed_files.append(filename)

    return bmis, genders, processed_files

def plot_bmi_distribution(bmis, bins=np.arange(0, 81, 5)):
    # Plot the BMI distribution
    plt.hist(bmis, bins=bins, edgecolor='black')
    plt.title('BMI Distribution')
    plt.xlabel('BMI')
    plt.ylabel('Number of files')
    plt.grid(True)
    plt.show()

# Directory to check
directory = r"C:\Users\USER\Desktop\korean\rename_men"

# Load the files from the directory and calculate BMI
bmis, genders, processed_files = load_files_from_directory(directory)

# Plot the BMI distribution
plot_bmi_distribution(bmis)

# %%
import os
import numpy as np
from collections import defaultdict

def check_bmi_distribution(bmis, genders, processed_files, bins=np.arange(0, 81, 5)):
    # Create a dictionary to hold files by BMI bin
    binned_files = defaultdict(list)
    
    # Bin the files by BMI ranges
    for bmi, gender, filename in zip(bmis, genders, processed_files):
        for i in range(len(bins) - 1):
            if bins[i] <= bmi < bins[i + 1]:
                binned_files[i].append(filename)
                break
    
    # Print out how many files exist in each BMI bin
    print("BMI Range Distribution:")
    for i in range(len(bins) - 1):
        print(f"{bins[i]} - {bins[i + 1]}: {len(binned_files[i])} files")
    
    return binned_files

# BMI 구간별로 파일 수를 확인
binned_files = check_bmi_distribution(bmis, genders, processed_files)
